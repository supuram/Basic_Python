# %% [markdown]
# # Notebook Imports and Packages

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Example1
# $f(x) = x^2 + x + 1$

# %%
def f(x):
    return x**2 + x + 1

# %%
x_1 = np.linspace(-3 , 3, 1000)

# %%
plt.plot(x_1, f(x_1))
plt.show()

# %% [markdown]
# # Finding the value of x that minimises f(x)

# %% [markdown]
# Slopes and Derivatives

# %%
#Derivative of f(x)
def df(x):
    return 2*x + 1

# %%
plt.figure(figsize = [10,4])

#1st plot
plt.subplot(1,2,1) #1 indicates 1 row, 2 indicates 2 columns
plt.xlabel('x')
plt.ylabel('f(x)')
plt.plot(x_1, f(x_1))

#2nd plot
plt.subplot(1,2,2)
plt.xlabel('x')
plt.ylabel(r'$\frac{df(x)}{dx}$') #The r before the string indicates that it is a raw string, which means that backslashes will be treated as literal backslashes rather than escape characters.
plt.plot(x_1, df(x_1))
plt.show()

# %% [markdown]
# ## Gradient Descent

# %%
new_x = 3
previous_x = 0
step_multiplier = 0.1
precision = 0.00001

for n in range(500):
    previous_x = new_x
    gradient = df(previous_x)
    new_x = previous_x - step_multiplier * gradient
    step_size = abs(new_x - previous_x)
    if step_size < precision:
        break
print('Local Minimum = ', new_x)
print('Value of df(x) = ', df(new_x))
print('f(x) value or cost at this point = ', f(new_x))
# Out:
# Local Minimum =  -0.49996003706460423
# Value of df(x) =  7.992587079153068e-05
# f(x) value or cost at this point =  0.7500000015970362
