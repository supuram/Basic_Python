# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import pandas as pd
data = pd.read_csv('lsd_math_score_data.csv')

# %%
time = data[['Time_Delay_in_Minutes']]
LSD = data[['LSD_ppm']]
score = data[['Avg_Math_Test_Score']]

# %%
plt.plot(time,LSD,color='b')
plt.title('Tissue concentration of LSD over time', fontsize = 17)
plt.xlabel('Time in minutes', fontsize = 14)
plt.ylabel('Tissue LSD ppm', fontsize = 14)
plt.text(x=0,y=0, s = 'Wagner et. al. (1968)')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %%
regr = LinearRegression()
regr.fit(LSD, score)
# Out:
# LinearRegression()

# %%
regr.coef_
# Out:
# array([[-9.00946642]])

# %%
regr.coef_[0]
# Out:
# array([-9.00946642])

# %%
print('Theta1/Slope of our graph = ',regr.coef_[0][0])
# Out:
# Theta1/Slope of our graph =  -9.009466415296783

# %%
regr.intercept_[0]
# Out:
# 89.12387376799306

# %%
print('R^2 value or Goodness of fit = ', regr.score(LSD, score))
# Out:
# R^2 value or Goodness of fit =  0.8778349707775888
